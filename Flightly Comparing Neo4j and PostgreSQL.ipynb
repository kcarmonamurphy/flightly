# %% [markdown]
# # Flightly
#
# Modelling 2015 US commercial airline flight queries using SQL and Neo4j

# %% [markdown]
# ### Setup Neo4j Query Object Wrapper
# This object will allow us to receive the result of the query and also measure the time it takes for X number of queries to be completed.

# %%
LINE_LIMIT = 20000

# %%
from neo4j import GraphDatabase
import timeit

neoconn = ('bolt://localhost:7687', 'neo4j', 'password')

class NeoQuery(object):
    def __init__(self, query):
        url, user, password = neoconn
        self._driver = GraphDatabase.driver(url, auth=(user, password))
        self._query = query

    def close(self):
        self._driver.close()
        
    def query(self, times=1):
        results = self._run_cypher()
        time = timeit.timeit(self._run_cypher, number=times)
        self.close()
        return results, time
        
    def _run_cypher(self):
        with self._driver.session() as session:
            return session.run(self._query)

# %% [markdown]
# ### Setup Postgres Query Wrapper

# %%
tmp = !pwd
current_path = tmp[0]

import psycopg2
from psycopg2 import Error
import timeit

pgconn = ('kevin', '', '127.0.0.1', '5432', 'flightly')

class PostgresQuery(object):
    def __init__(self, query):
        user, password, host, port, database = pgconn
        self._query = query
        try:
            self._connection = psycopg2.connect(
                user = user,
                password = password,
                host = host,
                port = port,
                database = database
            )
            self._cursor = self._connection.cursor()
        except:
            print("Failed to connect to PostgreSQL DB")

    def query(self, times=1):
        try:
            results = self._run_sql()
            time = timeit.timeit(self._run_sql, number=times)
            self._connection.commit()
            return results, time
        except (Exception, psycopg2.DatabaseError) as error :
            print ("Error while executing SQL command", error)
        finally:
            self._cursor.close()
            self._connection.close()
    
    def _run_sql(self):      
        self._cursor.execute(self._query)
        try:
            return self._cursor.fetchall()
        except:
            return []

# %% [markdown]
# ### Initialization queries
# Delete all of the existing nodes and relationships to start with clean slate.
# Then, load all the csv files into the DB

# %%
init_queries = {
    'delete_all': """
                   MATCH (n)
                   DETACH DELETE n
                   """,
    'load_airlines': """
            LOAD CSV FROM 'file:///flightly/airlines.csv' AS line
            CREATE (:Airline { name: line[1], iata: line[0]})
            """,
    'load_airports': """
            LOAD CSV FROM 'file:///flightly/airports.csv' AS line
            CREATE (:Airport { name: line[1], iata: line[0], city: line[2], state: line[3], country: line[4], latitude: line[5], longitude: line[6]})
            """,
    'load_flights': f"""
            USING PERIODIC COMMIT 1000
            LOAD CSV FROM 'file:///flightly/flights.csv' AS line
            WITH line LIMIT {LINE_LIMIT}
            CREATE (:Flight {{ 
                year: line[0],
                month: line[1],
                day: line[2],
                day_of_week: line[3],
                airline: line[4],
                flight_number: line[5],
                tail_number: line[6],
                origin_airport: line[7],
                destination_airport: line[8],
                scheduled_departure: line[9],
                departure_time: line[10],
                departure_delay: line[11],
                taxi_out: line[12],
                wheels_off: line[13],
                scheduled_time: line[14],
                elapsed_time: line[15],
                air_time: line[16],
                distance: line[17],
                wheels_on: line[18],
                taxi_in: line[19],
                scheduled_arrival: line[20],
                arrival_time: line[21],
                arrival_delay: line[22],
                diverted: line[23],
                cancelled: line[24],
                cancellation_reason: line[25],
                air_system_delay: line[26],
                security_delay: line[27],
                airline_delay: line[28],
                late_aircraft_delay: line[29],
                weather_delay: line[30]
            }})
            CREATE (:Tail {{
                number: line[6]
            }})
            """
}

for query in init_queries.items():
    NeoQuery(query[1]).query(0)

# %%
init_queries = {
    'drop_all_tables': """
        DROP SCHEMA public CASCADE;
        CREATE SCHEMA public;
        
        GRANT ALL ON SCHEMA public TO postgres;
        GRANT ALL ON SCHEMA public TO public;
        """,
    'create_airlines_table': """
        CREATE TABLE IF NOT EXISTS airlines (
          iata text,
          name text);
        """,
    'create_airports_table': """
        CREATE TABLE IF NOT EXISTS airports (
          iata text,
          name text,
          city text,
          state text,
          country text,
          latitude text,
          longitude text
          );
        """,
    'create_flights_table': """
        CREATE TABLE IF NOT EXISTS flights (
            year text,
            month text,
            day text,
            day_of_week text,
            airline text,
            flight_number text,
            tail_number text,
            origin_airport text,
            destination_airport text,
            scheduled_departure text,
            departure_time text,
            departure_delay text,
            taxi_out text,
            wheels_off text,
            scheduled_time text,
            elapsed_time text,
            air_time text,
            distance text,
            wheels_on text,
            taxi_in text,
            scheduled_arrival text,
            arrival_time text,
            arrival_delay text,
            diverted text,
            cancelled text,
            cancellation_reason text,
            air_system_delay text,
            security_delay text,
            airline_delay text,
            late_aircraft_delay text,
            weather_delay text
        );
        """,
    'load_airlines_csv': f"""
        COPY airlines
        FROM '{current_path}/csv/airlines.csv' DELIMITER ',' HEADER CSV;
        """,
    'load_airports_csv': f"""
        COPY airports
        FROM '{current_path}/csv/airports.csv' DELIMITER ',' HEADER CSV;
        """,
    'load_flights_csv': f"""
        COPY flights
        FROM PROGRAM 'head -{LINE_LIMIT+1} {current_path}/csv/flights.csv' DELIMITER ',' HEADER CSV;
        """
}

for query in init_queries.items():
    PostgresQuery(query[1]).query(0)

# %% [markdown]
# ### Match queries
# Create the relationships that...

# %%
match_queries = {
    'match_origin_airport': """
            MATCH (fl:Flight),(ap:Airport)
            WHERE fl.origin_airport = ap.iata
            CREATE (ap)-[r:HAS_DEPARTURE]->(fl)
            RETURN type(r)
            """,
        
    'match_destination_airport': """
            MATCH (fl:Flight),(ap:Airport)
            WHERE fl.destination_airport = ap.iata
            CREATE (fl)-[:FLIES_TO]->(ap)
            """,
    'match_airline': """
            MATCH (fl:Flight),(al:Airline)
            WHERE fl.airline = al.iata
            CREATE (fl)-[:OPERATED_BY]->(al)
            """,
    'match_tail': """
            MATCH (fl:Flight),(tl:Tail)
            WHERE fl.tail_number = tl.number
            CREATE (fl)-[:USES]->(tl)
            """
}

for query in match_queries.items():
    NeoQuery(query[1]).query(0)

# %% [markdown]
# ### Single table queries

# %%
# all flights out of ORD

nresults, ntime = NeoQuery(
    """
    MATCH (fl:Flight {origin_airport: 'ORD'})
    RETURN fl.flight_number
    """
).query(100)

presults, ptime = PostgresQuery(
    """
    SELECT flight_number from flights where origin_airport = 'ORD'
    """
).query(100)

#time and results

print(ntime)
nresults = [record[0] for record in nresults]

print(ptime)
presults = [record[0] for record in presults]

print(nresults)

list(set(presults) - set(nresults))
# Out:
# 2.8112205250000013
# 0.9193670300000001
# ['602', '1500', '409', '1167', '5498', '1012', '224', '977', '1256', '654', '5370', '5764', '1748', '729', '424', '1061', '296', '761', '725', '5299', '661', '4546', '1967', '731', '1070', '1524', '1001', '4498', '5622', '1440', '1610', '1620', '23', '5556', '1454', '6407', '6379', '6389', '709', '4401', '4993', '454', '1665', '4158', '815', '6378', '1161', '1688', '523', '1477', '792', '395', '5446', '549', '121', '6459', '245', '538', '3940', '6119', '5349', '5248', '382', '1272', '4284', '1684', '4712', '691', '761', '5447', '5626', '2259', '1185', '893', '195', '231', '632', '384', '2224', '3212', '1463', '139', '357', '6200', '2931', '3242', '1538', '3437', '1933', '1582', '4756', '6122', '2855', '5298', '1590', '1168', '810', '1551', '2485', '2839', '331', '2315', '2872', '3256', '3415', '906', '1437', '1534', '2813', '3138', '1703', '1169', '1412', '1759', '2246', '4722', '5904', '5694', '219', '2183', '2784', '3624', '5479', '4980', '5431', '202', '1058', '1452', '4377', '2836', '3181', '5978', '6159', '3075', '3094', '5295', '3164', '1375', '2356', '2877', '2757', '3274', '3965', '927', '380', '1620', '3460', '2632', '589', '1530', '1751', '302', '1201', '1693', '5691', '2838', '3180', '4730', '2023', '5436', '387', '2319', '2783', '2925', '3448', '4518', '2862', '219', '847', '1054', '1205', '3043', '3012', '2999', '2901', '865', '1693', '1563', '3058', '3475', '322', '1657', '2950', '3114', '5369', '1080', '3045', '186', '3004', '1566', '1763', '4589', '5919', '5925', '6149', '3456', '2646', '5161', '4670', '6188', '5364', '3956', '631', '1163', '758', '1723', '278', '6008', '3119', '5238', '1630', '1044', '3627', '2070', '2842', '2767', '3368', '3670', '2321', '4987', '521', '374', '3412', '1087', '1226', '159', '3228', '3356', '393', '5995', '719', '2361', '3132', '1685', '1343', '2752', '3266', '198', '6247', '682', '1065', '1679', '3686', '2941', '4992', '230', '1004', '1492', '2267', '3936', '4242', '4464', '4753', '2982', '3155', '3126', '3698', '5332', '5455', '1236', '5353', '5325', '416', '1233', '1606', '550', '4637', '1477', '3260', '3256', '4174', '4421', '6038', '5198', '4457', '5354', '3950', '368', '4294', '5726', '6167', '3101', '2325', '3020', '2635', '3172', '4973', '4512', '2863', '3339', '3423', '432', '5582', '552', '664', '1263', '3321', '5393', '474', '1502', '3934', '742', '231', '1644', '690', '3118', '1817', '197', '1067', '4509', '6165', '672', '1710', '1670', '4142', '3008', '409', '5413', '366', '2968', '3061', '659', '656', '1260', '2331', '2408', '4737', '2801', '2643', '1430', '155', '1135', '3258', '1141', '2890', '3289', '1583', '5737', '3637', '2335', '5903', '2854', '390', '985', '1432', '4103', '5994', '2849', '5924', '364', '1074', '2970', '3100', '1735', '1221', '2818', '983', '2826', '3028', '3072', '4990', '476', '4731', '4996', '1151', '2340', '3413', '3620', '29', '2929', '6225', '1290', '4334', '6469', '2917', '3469', '1555', '1612', '209', '2339', '1110', '5409', '1215', '1063', '3046', '245', '3097', '3498', '99', '6328', '151', '1612', '783', '690', '1419', '1475', '1605', '463', '2914', '3029', '1043', '4662', '360', '3073', '4349', '5361', '2640', '241', '1064', '2769', '1403', '3949', '4273', '2805', '2889', '5396', '1687', '5928', '2986', '2343', '6110', '5998', '4504', '1143', '1130', '1401', '2951', '518', '358', '3265', '3963', '1965', '475', '3297', '3108', '3585', '6365', '3263', '3947', '5339', '5566', '1271', '2992', '3244', '6314', '241', '1179', '354', '5201', '5205', '5408', '4727', '241', '2811', '3048', '4147', '563', '3227', '5412', '5233', '531', '2239', '3158', '3633', '93', '111', '5950', '6079', '3080', '3500', '5224', '223', '493', '1267', '5404', '2875', '2919', '3102', '6449', '333', '675', '6011', '425', '2636', '5511', '350', '2345', '4991', '2271', '1116', '6258', '2785', '1142', '5916', '5495', '6397', '624', '692', '1427', '2409', '6115', '3165', '630', '5329', '1196', '4742', '1623', '4110', '3003', '3961', '1094', '2823', '582', '1136', '5 ...
# []

# %%
# all flights with a delay of more than 100 minutes

nresults, ntime = NeoQuery(
    """
    MATCH (fl:Flight)
    WHERE toInteger(fl.departure_delay) > 100
    RETURN DISTINCT fl.flight_number
    """
).query(100)

presults, ptime = PostgresQuery(
    """
    SELECT flight_number from flights WHERE CAST (departure_delay AS INTEGER) > 100
    """
).query(100)

print(ntime)
nresults = [record[0] for record in nresults]

print(ptime)
presults = [record[0] for record in presults]

print(nresults)

list(set(presults) - set(nresults))
# Out:
# 5.520864553000003
# 1.3462678709999985
# ['1057', '824', '5976', '5547', '247', '1205', '943', '6420', '1492', '1966', '2522', '3432', '1207', '595', '705', '1195', '531', '1109', '2393', '110', '5242', '1499', '2567', '240', '4978', '3047', '2413', '6283', '337', '6458', '395', '974', '416', '567', '992', '258', '5518', '164', '749', '4712', '6323', '1623', '442', '6279', '4992', '169', '2591', '56', '3200', '1590', '5387', '43', '5315', '3492', '1532', '1221', '570', '5561', '5529', '1422', '2055', '239', '597', '4671', '1410', '5365', '123', '4479', '2389', '6183', '1531', '452', '4619', '4556', '1683', '5160', '1189', '1218', '3274', '306', '5919', '2317', '510', '1081', '2072', '7', '5384', '4264', '2773', '1437', '4540', '1605', '3214', '170', '5502', '5163', '5578', '6161', '820', '1180', '2417', '5', '4706', '5565', '2470', '399', '4447', '6011', '5183', '1391', '1263', '785', '489', '690', '5421', '1697', '821', '5997', '5204', '4654', '551', '305', '5171', '398', '386', '221', '2360', '598', '1636', '754', '4561', '2251', '6098', '5371', '2418', '3303', '4208', '1417', '203', '4989', '2809', '5498', '1987', '152', '1475', '1337', '1029', '5935', '2324', '586', '5212', '2639', '1149', '532', '1554', '1535', '942', '3118', '528', '287', '3226', '1091', '3647', '1668', '487', '51', '2922', '4526', '6538', '2345', '311', '2325', '1615', '4259', '1541', '8', '1116', '285', '3570', '60', '2478', '2466', '188', '741', '579', '2168', '928', '3590', '1502', '2774', '2157', '4840', '1704', '6213', '208', '1008', '2296', '6190', '1598', '4774', '3056', '1047', '156', '682', '102', '2524', '1355', '126', '822', '530', '1114', '5906', '6467', '457', '735', '2339', '4690', '763', '4541', '1643', '2534', '6256', '3659', '680', '5573', '1645', '2501', '2644', '4529', '3396', '380', '1537', '1439', '751', '1566', '1571', '1384', '1495', '1523', '2362', '1595', '581', '303', '2540', '4552', '1004', '5475', '2427', '2382', '1344', '2300', '1413', '697', '5465', '1840', '90', '6457', '4151', '2962', '3014', '3194', '6497', '1768', '612', '3609', '4809', '1158', '3443', '2775', '5291', '2253', '3082', '2407', '1703', '3188', '2319', '663', '2852', '130', '1408', '1232', '568', '4672', '5240', '5173', '4856', '245', '2250', '6322', '1752', '1146', '135', '1043', '1511', '6580', '2286', '5545', '44', '1444', '6228', '196', '1662', '388', '2263', '729', '5445', '455', '4169', '5534', '2215', '479', '5261', '6338', '1885', '1655', '2575', '297', '1217', '644', '1722', '587', '5614', '1132', '1629', '833', '290', '1175', '2210', '5458', '1927', '843', '358', '2278', '3301', '731', '1054', '5480']
# []

# %% [markdown]
# ### Using Relationships

# %%
# flights departing from Atlanta and arriving in Charlotte

nresults, ntime = NeoQuery(
    """
    MATCH (atl:Airport {iata: 'ATL'})-[:HAS_DEPARTURE]->(fl:Flight)-[:FLIES_TO]->(clt:Airport {iata: 'CLT'})
    RETURN fl.flight_number
    """
).query(200)

presults, ptime = PostgresQuery(
    """
    SELECT flight_number from flights WHERE origin_airport = 'ATL' AND destination_airport = 'CLT'
    """
).query(200)

print(ntime)
nresults = [record[0] for record in nresults]

print(ptime)
presults = [record[0] for record in presults]

print(nresults)

list(set(presults) - set(nresults))
# Out:
# 1.104647173
# 2.1296228699999986
# ['889', '447', '1805', '1808', '1808', '461', '1744', '1999', '2052', '1441', '2065', '1095', '2133', '1076', '461', '2251', '1095', '2065', '658']
# []

# %%
# flights departing from Chicago and arriving in Los Angeles operated by United

nresults, ntime = NeoQuery(
    """
    MATCH (ord:Airport {iata: 'ORD'})-[:HAS_DEPARTURE]->(fl:Flight)-[:FLIES_TO]->(lax:Airport {iata: 'LAX'}),
          (fl)-[:OPERATED_BY]->(ua:Airline {iata: 'UA'})
    RETURN fl.flight_number
    """
).query(200)

presults, ptime = PostgresQuery(
    """
    SELECT flight_number from flights WHERE origin_airport = 'ORD' AND destination_airport = 'LAX' AND airline = 'UA'
    """
).query(200)

print(ntime)
nresults = [record[0] for record in nresults]

print(ptime)
presults = [record[0] for record in presults]

print(nresults)

list(set(presults) - set(nresults))
# Out:
# 2.190588023
# 2.6001490329999974
# ['531', '1004', '661', '1168', '1256', '1058', '1037', '521', '1151', '1665', '1591', '661', '1037', '1760', '865']
# []

# %%
# flights departing from Chicago and arriving in Los Angeles operated by United with Tail Number N33209

nresults, ntime = NeoQuery(
    """
    MATCH (ord:Airport {iata: 'ORD'})-[:HAS_DEPARTURE]->(fl:Flight)-[:FLIES_TO]->(lax:Airport {iata: 'LAX'}),
          (fl)-[:OPERATED_BY]->(ua:Airline {iata: 'UA'}),
          (fl)-[:USES]->(tl:Tail {number: 'N33209'})
    RETURN DISTINCT fl.flight_number
    """
).query(200)

presults, ptime = PostgresQuery(
    """
    SELECT flight_number from flights WHERE origin_airport = 'ORD' AND destination_airport = 'LAX'
    AND airline = 'UA' AND tail_number = 'N33209'
    """
).query(200)

print(ntime)
nresults = [record[0] for record in nresults]

print(ptime)
presults = [record[0] for record in presults]

print(nresults)

list(set(presults) - set(nresults))
# Out:
# 3.345743089999999
# 2.7668735359999985
# ['1058']
# []

# %% [markdown]
# ### Joining across tables

# %%
# get names of the airlines operating flights from Chicago to Los Angeles

nresults, ntime = NeoQuery(
    """
    MATCH (ord:Airport {iata: 'ORD'})-[:HAS_DEPARTURE]->(fl:Flight)-[:FLIES_TO]->(lax:Airport {iata: 'LAX'}),
          (fl)-[:OPERATED_BY]->(al:Airline)
    RETURN DISTINCT al.name
    """
).query(200)

presults, ptime = PostgresQuery(
    """
    SELECT name from airlines INNER JOIN flights ON (airlines.iata = flights.airline)
    WHERE origin_airport = 'ORD' AND destination_airport = 'LAX'
    """
).query(200)

print(ntime)
nresults = [record[0] for record in nresults]

print(ptime)
presults = [record[0] for record in presults]

print(nresults)

list(set(presults) - set(nresults))
# Out:
# 1.7107797620000014
# 3.2483375779999974
# ['American Airlines Inc.', 'Spirit Air Lines', 'United Air Lines Inc.', 'Virgin America']
# []

# %%
# get the names of destination airports from all flights originating in Wyoming

nresults, ntime = NeoQuery(
    """
    MATCH (hi:Airport {state: 'WY'})-[:HAS_DEPARTURE]->(fl:Flight)-[:FLIES_TO]->(ap:Airport)
    RETURN DISTINCT ap.name
    """
).query(200)

presults, ptime = PostgresQuery(
    """
    SELECT name from airports
    JOIN flights ON (airports.iata = flights.destination_airport)
    where flights.origin_airport IN (SELECT iata from airports WHERE airports.state = 'WY')
    """
).query(200)

print(ntime)
nresults = [record[0] for record in nresults]

print(ptime)
presults = [record[0] for record in presults]

print(nresults)

list((set(presults) - set(nresults)))
# Out:
# 0.3012527409999848
# 2.547119858999963
# ['San Francisco International Airport', 'Rock Springs-Sweetwater County Airport', 'Gillette-Campbell County Airport', 'Salt Lake City International Airport', "Chicago O'Hare International Airport", 'Los Angeles International Airport', 'Dallas/Fort Worth International Airport', 'Minneapolis-Saint Paul International Airport', 'Hartsfield-Jackson Atlanta International Airport', 'Newark Liberty International Airport', 'George Bush Intercontinental Airport', 'Denver International Airport']
# []

# %%
# get possible connection airports on a flight from Alask to Florida

nresults, ntime = NeoQuery(
    """
    MATCH (ap1:Airport {state: 'AL'})-[:HAS_DEPARTURE]->(fl:Flight)-[:FLIES_TO]->(ap:Airport),
          (ap)-[:HAS_DEPARTURE]->(fl2:Flight)-[:FLIES_TO]->(ap2:Airport {state: 'FL'})
          
    WITH fl, fl2, ap, ap1, ap2,
         toInteger(left(fl.scheduled_arrival, 2)) * 60 + toInteger(right(fl.scheduled_arrival, 2)) as fl_arrival,
         toInteger(left(fl2.scheduled_departure, 2)) * 60 + toInteger(right(fl2.scheduled_departure, 2)) as fl2_departure  
    
    WHERE (fl2_departure - fl_arrival) > 60 AND (fl2_departure - fl_arrival) < 120 AND ap.state <> 'FL' AND fl.day = '1'
    
    RETURN DISTINCT ap1.name, fl.scheduled_departure, fl.scheduled_arrival, ap.name,
                    fl2.scheduled_departure, fl2.scheduled_arrival, ap2.name, (fl2_departure - fl_arrival) as layover_time
    """
).query(10)

print(ntime)
for record in nresults:
    print(f"""
    Flight departs from {record[0]} at {record[1]}.
    Arrival at {record[2]} in {record[3]}
    {record[7]} minutes layover time.
    Next leg departs at {record[4]} and lands at {record[5]} in {record[6]}
    """)
# Out:
# 1.1603698410008292
#
#     Flight departs from Birmingham-Shuttlesworth International Airport at 0645.
#     Arrival at 0900 in Dallas/Fort Worth International Airport
#     80 minutes layover time.
#     Next leg departs at 1020 and lands at 1400 in Fort Lauderdale-Hollywood International Airport
#
#
#     Flight departs from Birmingham-Shuttlesworth International Airport at 0645.
#     Arrival at 0900 in Dallas/Fort Worth International Airport
#     115 minutes layover time.
#     Next leg departs at 1055 and lands at 1435 in Miami International Airport
#
#
#     Flight departs from Birmingham-Shuttlesworth International Airport at 0645.
#     Arrival at 0900 in Dallas/Fort Worth International Airport
#     95 minutes layover time.
#     Next leg departs at 1035 and lands at 1213 in Pensacola International Airport (Pensacola Gulf Coast Regional Airport)
#
#
#     Flight departs from Birmingham-Shuttlesworth International Airport at 0645.
#     Arrival at 0900 in Dallas/Fort Worth International Airport
#     80 minutes layover time.
#     Next leg departs at 1020 and lands at 1348 in Southwest Florida International Airport
#
#
#     Flight departs from Birmingham-Shuttlesworth International Airport at 0645.
#     Arrival at 0900 in Dallas/Fort Worth International Airport
#     65 minutes layover time.
#     Next leg departs at 1005 and lands at 1303 in Tallahassee International Airport
#
#
#     Flight departs from Birmingham-Shuttlesworth International Airport at 0645.
#     Arrival at 0900 in Dallas/Fort Worth International Airport
#     94 minutes layover time.
#     Next leg departs at 1034 and lands at 1356 in Tampa International Airport
#
#
#     Flight departs from Birmingham-Shuttlesworth International Airport at 0645.
#     Arrival at 0900 in Dallas/Fort Worth International Airport
#     80 minutes layover time.
#     Next leg departs at 1020 and lands at 1335 in Tampa International Airport
#
#
#     Flight departs from Birmingham-Shuttlesworth International Airport at 0645.
#     Arrival at 0900 in Dallas/Fort Worth International Airport
#     115 minutes layover time.
#     Next leg departs at 1055 and lands at 1243 in Destin-Fort Walton Beach Airport/Eglin AFB
#
#
#     Flight departs from Birmingham-Shuttlesworth International Airport at 1700.
#     Arrival at 1901 in Hartsfield-Jackson Atlanta International Airport
#     110 minutes layover time.
#     Next leg departs at 2051 and lands at 2209 in Daytona Beach International Airport
#
#
#     Flight departs from Birmingham-Shuttlesworth International Airport at 1700.
#     Arrival at 1901 in Hartsfield-Jackson Atlanta International Airport
#     104 minutes layover time.
#     Next leg departs at 2045 and lands at 2235 in Fort Lauderdale-Hollywood International Airport
#
#
#     Flight departs from Birmingham-Shuttlesworth International Airport at 1700.
#     Arrival at 1901 in Hartsfield-Jackson Atlanta International Airport
#     79 minutes layover time.
#     Next leg departs at 2020 and lands at 2215 in Fort Lauderdale-Hollywood International Airport
#
#
#     Flight departs from Birmingham-Shuttlesworth International Airport at 1700.
#     Arrival at 1901 in Hartsfield-Jackson Atlanta International Airport
#     113 minutes layover time.
#     Next leg departs at 2054 and lands at 2204 in Gainesville Regional Airport
#
#
#     Flight departs from Birmingham-Shuttlesworth International Airport at 1700.
#     Arrival at 1901 in Hartsfield-Jackson Atlanta International Airport
#     104 minutes layover time.
#     Next leg departs at 2045 and lands at 2153 in Jacksonville International Airport
#
#
#     Flight departs from Birmingham-Shuttlesworth International Airport at 1700.
#     Arrival at 1901 in Hartsfield-Jackson Atlanta International Airport
#     114 minutes layover time.
#     Next leg departs at 2055 and lands at 2224 in Orlando International Airport
#
#
#     Flight departs from Birmingham-Shuttlesworth International Airport at 1700.
#     Arrival at 1901 in Hartsfield-Jackson Atlanta International Airport
#     119 minutes layover time.
#     Next leg departs at 2100 and lands at 2249 in Palm Beach International Airport
#
#
#     Flight departs from Birmingham-Shuttlesworth International Airport at 1700.
#     Arrival at 1901 in Hartsfield-Jackson Atlanta International Airport
#     100 minutes layover time.
#     Next leg departs at 2041 and lands at 2204 in Tampa International Airport
#
#
#     Flight departs from Birmingham-Shuttlesworth International Airport at 0900.
#     Arrival at 1100 in Hartsfield-Jackson Atlanta International Airport
#     65 minutes layover time.
#     Next leg departs at 1205 and lands at 1322 in Daytona Beach International Airport
#
#
#     Flight departs from Birmingham-Shuttlesworth International Airport at 0900.
#     Arrival at 1100 in Hartsfield-Jackson Atlanta International Airport
#     74 minutes layover time.
#     Next leg departs at 1214 and lands at 1326 in Gainesville Regional Airport
#
#
#     Flight departs from Birmingham-Shuttlesworth International Airport at 0900.
#     Arrival at 1100 in Hartsfield-Jackson Atlanta International Airport
#     85 minutes layover time.
#     Next leg departs at 1225 and lands at 1350 in Orlando International Airport
#
#
#     Flight departs from Birmingham-Shuttlesworth International Airport at 0900.
#     Arrival at 1100 in Hartsfield-Jackson Atlanta International Airport
#     72 minutes layover time.
#     Next leg departs at 1212 and lands at 1343 in Melbourne International Airport
#
#
#     Flight departs from Birmingham-Shuttlesworth International Airport at 0900.
#     Arrival at 1100 in Hartsfield-Jackson Atlanta International Airport
#     80 minutes layover time.
#     Next leg departs at 1220 and lands at 1410 in Palm Beach International Airport
#
#
#     Flight departs from Birmingham-Shuttlesworth International Airport at 0900.
#     Arrival at 1100 in Hartsfield-Jackson Atlanta International Airport
#     65 minutes layover time.
#     Next leg departs at 1205 and lands at 1347 in Southwest Florida International Airport
#
#
#     Flight departs from Birmingham-Shuttlesworth International Airport at 0900.
#     Arrival at 1100 in Hartsfield-Jackson Atlanta International Airport
#     100 minutes layover time.
#     Next leg departs at 1240 and lands at 1405 in Tampa International Airport
#
#
#     Flight departs from Birmingham-Shuttlesworth International Airport at 0900.
#     Arrival at 1100 in Hartsfield-Jackson Atlanta International Airport
#     90 minutes layover time.
#     Next leg departs at 1230 and lands at 1244 in Destin-Fort Walton Beach Airport/Eglin AFB
#
#
#     Flight departs from Birmingham-Shuttlesworth International Airport at 1625.
#     Arrival at 1820 in Dallas Love Field
#     85 minutes layover time.
#     Next leg departs at 1945 and lands at 2310 in Orlando International Airport
#
#
#     Flight departs from Birmingham-Shuttlesworth International Airport at 1625.
#     Arrival at 1820 in Dallas Love Field
#     110 minutes layover time.
#     Next leg departs at 2010 and lands at 2325 in Tampa International Airport
#
#
#     Flight departs from Birmingham-Shuttlesworth International Airport at 1129.
#     Arrival at 1431 in Detroit Metropolitan Airport
#     83 minutes layover time.
#     Next leg departs at 1554 and lands at 1851 in Southwest Florida International Airport
#
#
#     Flight departs from Birmingham-Shuttlesworth International Airport at 1129.
#     Arrival at 1431 in Detroit Metropolitan Airport
#     69 minutes layover time.
#     Next leg departs at 1540 and lands at 1826 in Tampa International Airport
#
#
#     Flight departs from Birmingham-Shuttlesworth International Airport at 1129.
#     Arrival at 1431 in Detroit Metropolitan Airport
#     88 minutes layover time.
#     Next leg departs at 1559 and lands at 1841 in Tampa International Airport
#
#
#     Flight departs from Birmingham-Shuttlesworth International Airport at 1050.
#     Arrival at 1245 in Chicago Midway International Airport
#     90 minutes layover time.
#     Next leg departs at 1415 and lands at 1810 in Fort Lauderdale-Hollywood International Airport
#
#
#     Flight departs from Birmingham-Shuttlesworth International Airport at 1050.
#     Arrival at 1245 in Chicago Midway International Airport
#     75 minutes layover time.
#     Next leg departs at 1400 and lands at 1710 in Jacksonville International Airport
#
#
#     Flight departs from Birmingham-Shuttlesworth International Airport at 1050.
#     Arrival at 1245 in Chicago Midway International Airport
#     75 minutes layover time.
#     Next leg departs at 1400 and lands at 1745 in Southwest Florida International Airport
#
#
#     Flight departs from Birmingham-Shuttlesworth International Airport at 1050.
#     Arrival at 1245 in Chicago Midway International Airport
#     105 minutes layover time.
#     Next leg departs at 1430 and lands at 1800 in Tampa International Airport
#
#
#     Flight departs from Birmingham-Shuttlesworth International Airport at 0850.
#     Arrival at 1145 in Baltimore-Washington International Airport
#     110 minutes layover time.
#     Next leg departs at 1335 and lands at 1610 in Fort Lauderdale-Hollywood International Airport
#
#
#     Flight departs from Birmingham-Shuttlesworth International Airport at 0850.
#     Arrival at 1145 in Baltimore-Washington International Airport
#     84 minutes layover time.
#     Next leg departs at 1309 and lands at 1550 in Miami International Airport
#
#
#     Flight departs from Birmingham-Shuttlesworth International Airport at 0850.
#     Arrival at 1145 in Baltimore-Washington International Airport
#     95 minutes layover time.
#     Next leg departs at 1320 and lands at 1550 in Palm Beach International Airport
#
#
#     Flight departs from Birmingham-Shuttlesworth International Airport at 0850.
#     Arrival at 1145 in Baltimore-Washington International Airport
#     105 minutes layover time.
#     Next leg departs at 1330 and lands at 1610 in Southwest Florida International Airport
#
#
#     Flight departs from Birmingham-Shuttlesworth International Airport at 1500.
#     Arrival at 1710 in Chicago O'Hare International Airport
#     113 minutes layover time.
#     Next leg departs at 1903 and lands at 2312 in Fort Lauderdale-Hollywood International Airport
#
#
#     Flight departs from Birmingham-Shuttlesworth International Airport at 1500.
#     Arrival at 1710 in Chicago O'Hare International Airport
#     115 minutes layover time.
#     Next leg departs at 1905 and lands at 2308 in Miami International Airport
#
#
#     Flight departs from Birmingham-Shuttlesworth International Airport at 1500.
#     Arrival at 1710 in Chicago O'Hare International Airport
#     83 minutes layover time.
#     Next leg departs at 1833 and lands at 2242 in Miami International Airport
#
#
#     Flight departs from Birmingham-Shuttlesworth International Airport at 1500.
#     Arrival at 1710 in Chicago O'Hare International Airport
#     110 minutes layover time.
#     Next leg departs at 1900 and lands at 2250 in Palm Beach International Airport
#
#
#     Flight departs from Birmingham-Shuttlesworth International Airport at 1500.
#     Arrival at 1710 in Chicago O'Hare International Airport
#     95 minutes layover time.
#     Next leg departs at 1845 and lands at 2230 in Southwest Florida International Airport
#
#
#     Flight departs from Birmingham-Shuttlesworth International Airport at 1500.
#     Arrival at 1710 in Chicago O'Hare International Airport
#     61 minutes layover time.
#     Next leg departs at 1811 and lands at 2154 in Tampa International Airport
#
#
#     Flight departs from Birmingham-Shuttlesworth International Airport at 1532.
#     Arrival at 1747 in Denver International Airport
#     73 minutes layover time.
#     Next leg departs at 1900 and lands at 0030 in Orlando International Airport
#
#
#     Flight departs from Birmingham-Shuttlesworth International Airport at 1045.
#     Arrival at 1255 in Dallas/Fort Worth International Airport
#     90 minutes layover time.
#     Next leg departs at 1425 and lands at 1805 in Fort Lauderdale-Hollywood International Airport
#
#
#     Flight departs from Birmingham-Shuttlesworth International Airport at 1045.
#     Arrival at 1255 in Dallas/Fort Worth International Airport
#     95 minutes layover time.
#     Next leg departs at 1430 and lands at 1745 in Jacksonville International Airport
#
#
#     Flight departs from Birmingham-Shuttlesworth International Airport at 1045.
#     Arrival at 1255 in Dallas/Fort Worth International Airport
#     80 minutes layover time.
#     Next leg departs at 1415 and lands at 1740 in Orlando International Airport
#
#
#     Flight departs from Birmingham-Shuttlesworth International Airport at 1103.
#     Arrival at 1305 in Hartsfield-Jackson Atlanta International Airport
#     115 minutes layover time.
#     Next leg departs at 1500 and lands at 1655 in Fort Lauderdale-Hollywood International Airport
#
#
#     Flight departs from Birmingham-Shuttlesworth International Airport at 1103.
#     Arrival at 1305 in Hartsfield-Jackson Atlanta International Airport
#     115 minutes layover time.
#     Next leg departs at 1500 and lands at 1615 in Jacksonville International Airport
#
#
#     Flight departs from Birmingham-Shuttlesworth International Airport at 1103.
#     Arrival at 1305 in Hartsfield-Jackson Atlanta International Airport
#     110 minutes layover time.
#     Next leg departs at 1455 and lands at 1624 in Orlando International Airport
#
#
#     Flight departs from Birmingham-Shuttlesworth International Airport at 1103.
#     Arrival at 1305 in Hartsfield-Jackson Atlanta International Airport
#     118 minutes layover time.
#     Next leg departs at 1503 and lands at 1521 in Pensacola International Airport (Pensacola Gulf Coast Regional Airport)
#
#
#     Flight departs from Birmingham-Shuttlesworth International Airport at 1103.
#     Arrival at 1305 in Hartsfield-Jackson Atlanta International Airport
#     115 minutes layover time.
#     Next leg departs at 1500 and lands at 1635 in Sarasota-Bradenton International Airport
#
#
#     Flight departs from Birmingham-Shuttlesworth International Airport at 1103.
#     Arrival at 1305 in Hartsfield-Jackson Atlanta International Airport
#     90 minutes layover time.
#     Next leg departs at 1435 and lands at 1600 in Tampa International Airport
#
#
#     Flight departs from Birmingham-Shuttlesworth International Airport at 1440.
#     Arrival at 1636 in George Bush Intercontinental Airport
#     78 minutes layover time.
#     Next leg departs at 1754 and lands at 2105 in Orlando International Airport
#
#
#     Flight departs from Birmingham-Shuttlesworth International Airport at 1145.
#     Arrival at 1335 in Dallas Love Field
#     70 minutes layover time.
#     Next leg departs at 1445 and lands at 1820 in Fort Lauderdale-Hollywood International Airport
#
#
#     Flight departs from Birmingham-Shuttlesworth International Airport at 1710.
#     Arrival at 1920 in Dallas/Fort Worth International Airport
#     80 minutes layover time.
#     Next leg departs at 2040 and lands at 0015 in Fort Lauderdale-Hollywood International Airport
#
#
#     Flight departs from Birmingham-Shuttlesworth International Airport at 1710.
#     Arrival at 1920 in Dallas/Fort Worth International Airport
#     75 minutes layover time.
#     Next leg departs at 2035 and lands at 0011 in Miami International Airport
#
#
#     Flight departs from Birmingham-Shuttlesworth International Airport at 1710.
#     Arrival at 1920 in Dallas/Fort Worth International Airport
#     75 minutes layover time.
#     Next leg departs at 2035 and lands at 0005 in Palm Beach International Airport
#
#
#     Flight departs from Birmingham-Shuttlesworth International Airport at 1710.
#     Arrival at 1920 in Dallas/Fort Worth International Airport
#     70 minutes layover time.
#     Next leg departs at 2030 and lands at 2355 in Southwest Florida International Airport
#
#
#     Flight departs from Birmingham-Shuttlesworth International Airport at 1710.
#     Arrival at 1920 in Dallas/Fort Worth International Airport
#     80 minutes layover time.
#     Next leg departs at 2040 and lands at 2355 in Tampa International Airport
#
#
#     Flight departs from Birmingham-Shuttlesworth International Airport at 0840.
#     Arrival at 1032 in George Bush Intercontinental Airport
#     95 minutes layover time.
#     Next leg departs at 1207 and lands at 1518 in Orlando International Airport
#
#
#     Flight departs from Birmingham-Shuttlesworth International Airport at 0840.
#     Arrival at 1032 in George Bush Intercontinental Airport
#     118 minutes layover time.
#     Next leg departs at 1230 and lands at 1555 in Miami International Airport
#
#
#     Flight departs from Birmingham-Shuttlesworth International Airport at 0645.
#     Arrival at 0854 in Hartsfield-Jackson Atlanta International Airport
#     116 minutes layover time.
#     Next leg departs at 1050 and lands at 1102 in Northwest Florida Beaches International Airport
#
#
#     Flight departs from Birmingham-Shuttlesworth International Airport at 0645.
#     Arrival at 0854 in Hartsfield-Jackson Atlanta International Airport
#     66 minutes layover time.
#     Next leg departs at 1000 and lands at 1200 in Fort Lauderdale-Hollywood International Airport
#
#
#     Flight departs from Birmingham-Shuttlesworth International Airport at 0645.
#     Arrival at 0854 in Hartsfield-Jackson Atlanta International Airport
#     81 minutes layover time.
#     Next leg departs at 1015 and lands at 1213 in Fort Lauderdale-Hollywood International Airport
#
#
#     Flight departs from Birmingham-Shuttlesworth International Airport at 0645.
#     Arrival at 0854 in Hartsfield-Jackson Atlanta International Airport
#     61 minutes layover time.
#     Next leg departs at 0955 and lands at 1102 in Jacksonville International Airport
#
#
#     Flight departs from Birmingham-Shuttlesworth International Airport at 0645.
#     Arrival at 0854 in Hartsfield-Jackson Atlanta International Airport
#     61 minutes layover time.
#     Next leg departs at 0955 and lands at 1130 in Orlando International Airport
#
#
#     Flight departs from Birmingham-Shuttlesworth International Airport at 0645.
#     Arrival at 0854 in Hartsfield-Jackson Atlanta International Airport
#     66 minutes layover time.
#     Next leg departs at 1000 and lands at 1202 in Miami International Airport
#
#
#     Flight departs from Birmingham-Shuttlesworth International Airport at 0645.
#     Arrival at 0854 in Hartsfield-Jackson Atlanta International Airport
#     96 minutes layover time.
#     Next leg departs at 1030 and lands at 1220 in Palm Beach International Airport
#
#
#     Flight departs from Birmingham-Shuttlesworth International Airport at 0645.
#     Arrival at 0854 in Hartsfield-Jackson Atlanta International Airport
#     96 minutes layover time.
#     Next leg departs at 1030 and lands at 1206 in Sarasota-Bradenton International Airport
#
#
#     Flight departs from Birmingham-Shuttlesworth International Airport at 0645.
#     Arrival at 0854 in Hartsfield-Jackson Atlanta International Airport
#     101 minutes layover time.
#     Next leg departs at 1035 and lands at 1203 in Tampa International Airport
#
#
#     Flight departs from Dothan Regional Airport at 1412.
#     Arrival at 1609 in Hartsfield-Jackson Atlanta International Airport
#     66 minutes layover time.
#     Next leg departs at 1715 and lands at 1905 in Fort Lauderdale-Hollywood International Airport
#
#
#     Flight departs from Dothan Regional Airport at 1412.
#     Arrival at 1609 in Hartsfield-Jackson Atlanta International Airport
#     96 minutes layover time.
#     Next leg departs at 1745 and lands at 1852 in Jacksonville International Airport
#
#
#     Flight departs from Dothan Regional Airport at 1412.
#     Arrival at 1609 in Hartsfield-Jackson Atlanta International Airport
#     116 minutes layover time.
#     Next leg departs at 1805 and lands at 1915 in Jacksonville International Airport
#
#
#     Flight departs from Dothan Regional Airport at 1412.
#     Arrival at 1609 in Hartsfield-Jackson Atlanta International Airport
#     106 minutes layover time.
#     Next leg departs at 1755 and lands at 1925 in Orlando International Airport
#
#
#     Flight departs from Dothan Regional Airport at 1412.
#     Arrival at 1609 in Hartsfield-Jackson Atlanta International Airport
#     66 minutes layover time.
#     Next leg departs at 1715 and lands at 1840 in Orlando International Airport
#
#
#     Flight departs from Dothan Regional Airport at 1412.
#     Arrival at 1609 in Hartsfield-Jackson Atlanta International Airport
#     101 minutes layover time.
#     Next leg departs at 1750 and lands at 1948 in Miami International Airport
#
#
#     Flight departs from Dothan Regional Airport at 1412.
#     Arrival at 1609 in Hartsfield-Jackson Atlanta International Airport
#     86 minutes layover time.
#     Next leg departs at 1735 and lands at 1925 in Palm Beach International Airport
#
#
#     Flight departs from Dothan Regional Airport at 1412.
#     Arrival at 1609 in Hartsfield-Jackson Atlanta International Airport
#     89 minutes layover time.
#     Next leg departs at 1738 and lands at 1751 in Pensacola International Airport (Pensacola Gulf Coast Regional Airport)
#
#
#     Flight departs from Dothan Regional Airport at 1412.
#     Arrival at 1609 in Hartsfield-Jackson Atlanta International Airport
#     76 minutes layover time.
#     Next leg departs at 1725 and lands at 1850 in Tampa International Airport
#
#
#     Flight departs from Dothan Regional Airport at 1412.
#     Arrival at 1609 in Hartsfield-Jackson Atlanta International Airport
#     116 minutes layover time.
#     Next leg departs at 1805 and lands at 1930 in Tampa International Airport
#
#
#     Flight departs from Dothan Regional Airport at 1051.
#     Arrival at 1248 in Hartsfield-Jackson Atlanta International Airport
#     62 minutes layover time.
#     Next leg departs at 1350 and lands at 1520 in Orlando International Airport
#
#
#     Flight departs from Dothan Regional Airport at 1051.
#     Arrival at 1248 in Hartsfield-Jackson Atlanta International Airport
#     67 minutes layover time.
#     Next leg departs at 1355 and lands at 1525 in Orlando International Airport
#
#
#     Flight departs from Dothan Regional Airport at 1051.
#     Arrival at 1248 in Hartsfield-Jackson Atlanta International Airport
#     62 minutes layover time.
#     Next leg departs at 1350 and lands at 1549 in Miami International Airport
#
#
#     Flight departs from Dothan Regional Airport at 1051.
#     Arrival at 1248 in Hartsfield-Jackson Atlanta International Airport
#     69 minutes layover time.
#     Next leg departs at 1357 and lands at 1549 in Palm Beach International Airport
#
#
#     Flight departs from Dothan Regional Airport at 1051.
#     Arrival at 1248 in Hartsfield-Jackson Atlanta International Airport
#     67 minutes layover time.
#     Next leg departs at 1355 and lands at 1541 in Southwest Florida International Airport
#
#
#     Flight departs from Dothan Regional Airport at 1051.
#     Arrival at 1248 in Hartsfield-Jackson Atlanta International Airport
#     67 minutes layover time.
#     Next leg departs at 1355 and lands at 1501 in Tallahassee International Airport
#
#
#     Flight departs from Dothan Regional Airport at 1051.
#     Arrival at 1248 in Hartsfield-Jackson Atlanta International Airport
#     107 minutes layover time.
#     Next leg departs at 1435 and lands at 1600 in Tampa International Airport
#
#
#     Flight departs from Huntsville International Airport at 1045.
#     Arrival at 1243 in Hartsfield-Jackson Atlanta International Airport
#     62 minutes layover time.
#     Next leg departs at 1345 and lands at 1539 in Key West International Airport
#
#
#     Flight departs from Huntsville International Airport at 1045.
#     Arrival at 1243 in Hartsfield-Jackson Atlanta International Airport
#     67 minutes layover time.
#     Next leg departs at 1350 and lands at 1520 in Orlando International Airport
#
#
#     Flight departs from Huntsville International Airport at 1045.
#     Arrival at 1243 in Hartsfield-Jackson Atlanta International Airport
#     72 minutes layover time.
#     Next leg departs at 1355 and lands at 1525 in Orlando International Airport
#
#
#     Flight departs from Huntsville International Airport at 1045.
#     Arrival at 1243 in Hartsfield-Jackson Atlanta International Airport
#     67 minutes layover time.
#     Next leg departs at 1350 and lands at 1549 in Miami International Airport
#
#
#     Flight departs from Huntsville International Airport at 1045.
#     Arrival at 1243 in Hartsfield-Jackson Atlanta International Airport
#     74 minutes layover time.
#     Next leg departs at 1357 and lands at 1549 in Palm Beach International Airport
#
#
#     Flight departs from Huntsville International Airport at 1045.
#     Arrival at 1243 in Hartsfield-Jackson Atlanta International Airport
#     63 minutes layover time.
#     Next leg departs at 1346 and lands at 1401 in Pensacola International Airport (Pensacola Gulf Coast Regional Airport)
#
#
#     Flight departs from Huntsville International Airport at 1045.
#     Arrival at 1243 in Hartsfield-Jackson Atlanta International Airport
#     72 minutes layover time.
#     Next leg departs at 1355 and lands at 1541 in Southwest Florida International Airport
#
#
#     Flight departs from Huntsville International Airport at 1045.
#     Arrival at 1243 in Hartsfield-Jackson Atlanta International Airport
#     72 minutes layover time.
#     Next leg departs at 1355 and lands at 1501 in Tallahassee International Airport
#
#
#     Flight departs from Huntsville International Airport at 1045.
#     Arrival at 1243 in Hartsfield-Jackson Atlanta International Airport
#     112 minutes layover time.
#     Next leg departs at 1435 and lands at 1600 in Tampa International Airport
#
#
#     Flight departs from Huntsville International Airport at 1635.
#     Arrival at 1845 in Dallas/Fort Worth International Airport
#     115 minutes layover time.
#     Next leg departs at 2040 and lands at 0015 in Fort Lauderdale-Hollywood International Airport
#
#
#     Flight departs from Huntsville International Airport at 1635.
#     Arrival at 1845 in Dallas/Fort Worth International Airport
#     90 minutes layover time.
#     Next leg departs at 2015 and lands at 2335 in Orlando International Airport
#
#
#     Flight departs from Huntsville International Airport at 1635.
#     Arrival at 1845 in Dallas/Fort Worth International Airport
#     110 minutes layover time.
#     Next leg departs at 2035 and lands at 0011 in Miami International Airport
#
#
#     Flight departs from Huntsville International Airport at 1635.
#     Arrival at 1845 in Dallas/Fort Worth International Airport
#     110 minutes layover time.
#     Next leg departs at 2035 and lands at 0005 in Palm Beach International Airport
#
#
#     Flight departs from Huntsville International Airport at 1635.
#     Arrival at 1845 in Dallas/Fort Worth International Airport
#     105 minutes layover time.
#     Next leg departs at 2030 and lands at 2355 in Southwest Florida International Airport
#
#
#     Flight departs from Huntsville International Airport at 1635.
#     Arrival at 1845 in Dallas/Fort Worth International Airport
#     115 minutes layover time.
#     Next leg departs at 2040 and lands at 2355 in Tampa International Airport
#
#
#     Flight departs from Huntsville International Airport at 1635.
#     Arrival at 1845 in Dallas/Fort Worth International Airport
#     85 minutes layover time.
#     Next leg departs at 2010 and lands at 2158 in Destin-Fort Walton Beach Airport/Eglin AFB
#
#
#     Flight departs from Huntsville International Airport at 1402.
#     Arrival at 1550 in Chicago O'Hare International Airport
#     100 minutes layover time.
#     Next leg departs at 1730 and lands at 2136 in Fort Lauderdale-Hollywood International Airport
#
#
#     Flight departs from Huntsville International Airport at 1402.
#     Arrival at 1550 in Chicago O'Hare International Airport
#     91 minutes layover time.
#     Next leg departs at 1721 and lands at 2112 in Southwest Florida International Airport
#
#
#     Flight departs from Huntsville International Airport at 1431.
#     Arrival at 1624 in Hartsfield-Jackson Atlanta International Airport
#     81 minutes layover time.
#     Next leg departs at 1745 and lands at 1852 in Jacksonville International Airport
#
#
#     Flight departs from Huntsville International Airport at 1431.
#     Arrival at 1624 in Hartsfield-Jackson Atlanta International Airport
#     101 minutes layover time.
#     Next leg departs at 1805 and lands at 1915 in Jacksonville International Airport
#
#
#     Flight departs from Huntsville International Airport at 1431.
#     Arrival at 1624 in Hartsfield-Jackson Atlanta International Airport
#     91 minutes layover time.
#     Next leg departs at 1755 and lands at 1925 in Orlando International Airport
#
#
#     Flight departs from Huntsville International Airport at 1431.
#     Arrival at 1624 in Hartsfield-Jackson Atlanta International Airport
#     86 minutes layover time.
#     Next leg departs at 1750 and lands at 1948 in Miami International Airport
#
#
#     Flight departs from Huntsville International Airport at 1431.
#     Arrival at 1624 in Hartsfield-Jackson Atlanta International Airport
#     71 minutes layover time.
#     Next leg departs at 1735 and lands at 1925 in Palm Beach International Airport
#
#
#     Flight departs from Huntsville International Airport at 1431.
#     Arrival at 1624 in Hartsfield-Jackson Atlanta International Airport
#     74 minutes layover time.
#     Next leg departs at 1738 and lands at 1751 in Pensacola International Airport (Pensacola Gulf Coast Regional Airport)
#
#
#     Flight departs from Huntsville International Airport at 1431.
#     Arrival at 1624 in Hartsfield-Jackson Atlanta International Airport
#     61 minutes layover time.
#     Next leg departs at 1725 and lands at 1850 in Tampa International Airport
#
#
#     Flight departs from Huntsville International Airport at 1431.
#     Arrival at 1624 in Hartsfield-Jackson Atlanta International Airport
#     101 minutes layover time.
#     Next leg departs at 1805 and lands at 1930 in Tampa International Airport
#
#
#     Flight departs from Huntsville International Airport at 1431.
#     Arrival at 1624 in Hartsfield-Jackson Atlanta International Airport
#     106 minutes layover time.
#     Next leg departs at 1810 and lands at 1825 in Destin-Fort Walton Beach Airport/Eglin AFB
#
#
#     Flight departs from Huntsville International Airport at 0655.
#     Arrival at 0905 in Chicago O'Hare International Airport
#     75 minutes layover time.
#     Next leg departs at 1020 and lands at 1343 in Jacksonville International Airport
#
#
#     Flight departs from Huntsville International Airport at 0655.
#     Arrival at 0905 in Chicago O'Hare International Airport
#     102 minutes layover time.
#     Next leg departs at 1047 and lands at 1429 in Orlando International Airport
#
#
#     Flight departs from Huntsville International Airport at 0655.
#     Arrival at 0905 in Chicago O'Hare International Airport
#     93 minutes layover time.
#     Next leg departs at 1038 and lands at 1415 in Orlando International Airport
#
#
#     Flight departs from Huntsville International Airport at 0655.
#     Arrival at 0905 in Chicago O'Hare International Airport
#     105 minutes layover time.
#     Next leg departs at 1050 and lands at 1420 in Orlando International Airport
#
#
#     Flight departs from Huntsville International Airport at 0655.
#     Arrival at 0905 in Chicago O'Hare International Airport
#     108 minutes layover time.
#     Next leg departs at 1053 and lands at 1435 in Orlando International Airport
#
#
#     Flight departs from Huntsville International Airport at 0655.
#     Arrival at 0905 in Chicago O'Hare International Airport
#     65 minutes layover time.
#     Next leg departs at 1010 and lands at 1400 in Palm Beach International Airport
#
#
#     Flight departs from Huntsville International Airport at 0655.
#     Arrival at 0905 in Chicago O'Hare International Airport
#     90 minutes layover time.
#     Next leg departs at 1035 and lands at 1415 in Southwest Florida International Airport
#
#
#     Flight departs from Huntsville International Airport at 1025.
#     Arrival at 1235 in Dallas/Fort Worth International Airport
#     110 minutes layover time.
#     Next leg departs at 1425 and lands at 1805 in Fort Lauderdale-Hollywood International Airport
#
#
#     Flight departs from Huntsville International Airport at 1025.
#     Arrival at 1235 in Dallas/Fort Worth International Airport
#     115 minutes layover time.
#     Next leg departs at 1430 and lands at 1745 in Jacksonville International Airport
#
#
#     Flight departs from Huntsville International Airport at 1025.
#     Arrival at 1235 in Dallas/Fort Worth International Airport
#     100 minutes layover time.
#     Next leg departs at 1415 and lands at 1740 in Orlando International Airport
#
#
#     Flight departs from Huntsville International Airport at 1025.
#     Arrival at 1235 in Dallas/Fort Worth International Airport
#     77 minutes layover time.
#     Next leg departs at 1352 and lands at 1735 in Miami International Airport
#
#
#     Flight departs from Huntsville International Airport at 1025.
#     Arrival at 1235 in Dallas/Fort Worth International Airport
#     70 minutes layover time.
#     Next leg departs at 1345 and lands at 1528 in Pensacola International Airport (Pensacola Gulf Coast Regional Airport)
#
#
#     Flight departs from Huntsville International Airport at 1025.
#     Arrival at 1235 in Dallas/Fort Worth International Airport
#     80 minutes layover time.
#     Next leg departs at 1355 and lands at 1720 in Southwest Florida International Airport
#
#
#     Flight departs from Huntsville International Airport at 1739.
#     Arrival at 1944 in Hartsfield-Jackson Atlanta International Airport
#     67 minutes layover time.
#     Next leg departs at 2051 and lands at 2209 in Daytona Beach International Airport
#
#
#     Flight departs from Huntsville International Airport at 1739.
#     Arrival at 1944 in Hartsfield-Jackson Atlanta International Airport
#     61 minutes layover time.
#     Next leg departs at 2045 and lands at 2235 in Fort Lauderdale-Hollywood International Airport
#
#
#     Flight departs from Huntsville International Airport at 1739.
#     Arrival at 1944 in Hartsfield-Jackson Atlanta International Airport
#     70 minutes layover time.
#     Next leg departs at 2054 and lands at 2204 in Gainesville Regional Airport
#
#
#     Flight departs from Huntsville International Airport at 1739.
#     Arrival at 1944 in Hartsfield-Jackson Atlanta International Airport
#     61 minutes layover time.
#     Next leg departs at 2045 and lands at 2153 in Jacksonville International Airport
#
#
#     Flight departs from Huntsville International Airport at 1739.
#     Arrival at 1944 in Hartsfield-Jackson Atlanta International Airport
#     71 minutes layover time.
#     Next leg departs at 2055 and lands at 2224 in Orlando International Airport
#
#
#     Flight departs from Huntsville International Airport at 1739.
#     Arrival at 1944 in Hartsfield-Jackson Atlanta International Airport
#     106 minutes layover time.
#     Next leg departs at 2130 and lands at 2305 in Orlando International Airport
#
#
#     Flight departs from Huntsville International Airport at 1739.
#     Arrival at 1944 in Hartsfield-Jackson Atlanta International Airport
#     86 minutes layover time.
#     Next leg departs at 2110 and lands at 2302 in Miami International Airport
#
#
#     Flight departs from Huntsville International Airport at 1739.
#     Arrival at 1944 in Hartsfield-Jackson Atlanta International Airport
#     78 minutes layover time.
#     Next leg departs at 2102 and lands at 2233 in Melbourne International Airport
#
#
#     Flight departs from Huntsville International Airport at 1739.
#     Arrival at 1944 in Hartsfield-Jackson Atlanta International Airport
#     76 minutes layover time.
#     Next leg departs at 2100 and lands at 2249 in Palm Beach International Airport
#
#
#     Flight departs from Huntsville International Airport at 1739.
#     Arrival at 1944 in Hartsfield-Jackson Atlanta International Airport
#     84 minutes layover time.
#     Next leg departs at 2108 and lands at 2215 in Tallahassee International Airport
#
#
#     Flight departs from Huntsville International Airport at 0650.
#     Arrival at 0858 in Hartsfield-Jackson Atlanta International Airport
#     112 minutes layover time.
#     Next leg departs at 1050 and lands at 1102 in Northwest Florida Beaches International Airport
#
#
#     Flight departs from Huntsville International Airport at 0650.
#     Arrival at 0858 in Hartsfield-Jackson Atlanta International Airport
#     62 minutes layover time.
#     Next leg departs at 1000 and lands at 1200 in Fort Lauderdale-Hollywood International Airport
#
#
#     Flight departs from Huntsville International Airport at 0650.
#     Arrival at 0858 in Hartsfield-Jackson Atlanta International Airport
#     77 minutes layover time.
#     Next leg departs at 1015 and lands at 1213 in Fort Lauderdale-Hollywood International Airport
#
#
#     Flight departs from Huntsville International Airport at 0650.
#     Arrival at 0858 in Hartsfield-Jackson Atlanta International Airport
#     117 minutes layover time.
#     Next leg departs at 1055 and lands at 1209 in Gainesville Regional Airport
#
#
#     Flight departs from Huntsville International Airport at 0650.
#     Arrival at 0858 in Hartsfield-Jackson Atlanta International Airport
#     117 minutes layover time.
#     Next leg departs at 1055 and lands at 1230 in Orlando International Airport
#
#
#     Flight departs from Huntsville International Airport at 0650.
#     Arrival at 0858 in Hartsfield-Jackson Atlanta International Airport
#     62 minutes layover time.
#     Next leg departs at 1000 and lands at 1202 in Miami International Airport
#
#
#     Flight departs from Huntsville International Airport at 0650.
#     Arrival at 0858 in Hartsfield-Jackson Atlanta International Airport
#     92 minutes layover time.
#     Next leg departs at 1030 and lands at 1220 in Palm Beach International Airport
#
#
#     Flight departs from Huntsville International Airport at 0650.
#     Arrival at 0858 in Hartsfield-Jackson Atlanta International Airport
#     119 minutes layover time.
#     Next leg departs at 1057 and lands at 1120 in Pensacola International Airport (Pensacola Gulf Coast Regional Airport)
#
#
#     Flight departs from Huntsville International Airport at 0650.
#     Arrival at 0858 in Hartsfield-Jackson Atlanta International Airport
#     116 minutes layover time.
#     Next leg departs at 1054 and lands at 1242 in Southwest Florida International Airport
#
#
#     Flight departs from Huntsville International Airport at 0650.
#     Arrival at 0858 in Hartsfield-Jackson Atlanta International Airport
#     92 minutes layover time.
#     Next leg departs at 1030 and lands at 1206 in Sarasota-Bradenton International Airport
#
#
#     Flight departs from Huntsville International Airport at 0650.
#     Arrival at 0858 in Hartsfield-Jackson Atlanta International Airport
#     97 minutes layover time.
#     Next leg departs at 1035 and lands at 1203 in Tampa International Airport
#
#
#     Flight departs from Huntsville International Airport at 1300.
#     Arrival at 1505 in Dallas/Fort Worth International Airport
#     96 minutes layover time.
#     Next leg departs at 1641 and lands at 2025 in Fort Lauderdale-Hollywood International Airport
#
#
#     Flight departs from Huntsville International Airport at 1300.
#     Arrival at 1505 in Dallas/Fort Worth International Airport
#     105 minutes layover time.
#     Next leg departs at 1650 and lands at 1828 in Pensacola International Airport (Pensacola Gulf Coast Regional Airport)
#
#
#     Flight departs from Huntsville International Airport at 1300.
#     Arrival at 1505 in Dallas/Fort Worth International Airport
#     70 minutes layover time.
#     Next leg departs at 1615 and lands at 1803 in Destin-Fort Walton Beach Airport/Eglin AFB
#
#
#     Flight departs from Huntsville International Airport at 1238.
#     Arrival at 1440 in George Bush Intercontinental Airport
#     65 minutes layover time.
#     Next leg departs at 1545 and lands at 1910 in Fort Lauderdale-Hollywood International Airport
#
#
#     Flight departs from Huntsville International Airport at 1238.
#     Arrival at 1440 in George Bush Intercontinental Airport
#     76 minutes layover time.
#     Next leg departs at 1556 and lands at 1908 in Orlando International Airport
#
#
#     Flight departs from Huntsville International Airport at 1238.
#     Arrival at 1440 in George Bush Intercontinental Airport
#     117 minutes layover time.
#     Next leg departs at 1637 and lands at 1804 in Pensacola International Airport (Pensacola Gulf Coast Regional Airport)
#
#
#     Flight departs from Montgomery Regional Airport at 0630.
#     Arrival at 0845 in Dallas/Fort Worth International Airport
#     95 minutes layover time.
#     Next leg departs at 1020 and lands at 1400 in Fort Lauderdale-Hollywood International Airport
#
#
#     Flight departs from Montgomery Regional Airport at 0630.
#     Arrival at 0845 in Dallas/Fort Worth International Airport
#     110 minutes layover time.
#     Next leg departs at 1035 and lands at 1213 in Pensacola International Airport (Pensacola Gulf Coast Regional Airport)
#
#
#     Flight departs from Montgomery Regional Airport at 0630.
#     Arrival at 0845 in Dallas/Fort Worth International Airport
#     95 minutes layover time.
#     Next leg departs at 1020 and lands at 1348 in Southwest Florida International Airport
#
#
#     Flight departs from Montgomery Regional Airport at 0630.
#     Arrival at 0845 in Dallas/Fort Worth International Airport
#     80 minutes layover time.
#     Next leg departs at 1005 and lands at 1303 in Tallahassee International Airport
#
#
#     Flight departs from Montgomery Regional Airport at 0630.
#     Arrival at 0845 in Dallas/Fort Worth International Airport
#     109 minutes layover time.
#     Next leg departs at 1034 and lands at 1356 in Tampa International Airport
#
#
#     Flight departs from Montgomery Regional Airport at 0630.
#     Arrival at 0845 in Dallas/Fort Worth International Airport
#     95 minutes layover time.
#     Next leg departs at 1020 and lands at 1335 in Tampa International Airport
#
#
#     Flight departs from Montgomery Regional Airport at 1105.
#     Arrival at 1310 in Dallas/Fort Worth International Airport
#     75 minutes layover time.
#     Next leg departs at 1425 and lands at 1805 in Fort Lauderdale-Hollywood International Airport
#
#
#     Flight departs from Montgomery Regional Airport at 1105.
#     Arrival at 1310 in Dallas/Fort Worth International Airport
#     80 minutes layover time.
#     Next leg departs at 1430 and lands at 1745 in Jacksonville International Airport
#
#
#     Flight departs from Montgomery Regional Airport at 1105.
#     Arrival at 1310 in Dallas/Fort Worth International Airport
#     65 minutes layover time.
#     Next leg departs at 1415 and lands at 1740 in Orlando International Airport
#
#
#     Flight departs from Montgomery Regional Airport at 1105.
#     Arrival at 1310 in Dallas/Fort Worth International Airport
#     110 minutes layover time.
#     Next leg departs at 1500 and lands at 1815 in Tampa International Airport
#
#
#     Flight departs from Montgomery Regional Airport at 0615.
#     Arrival at 0806 in Hartsfield-Jackson Atlanta International Airport
#     86 minutes layover time.
#     Next leg departs at 0932 and lands at 1051 in Daytona Beach International Airport
#
#
#     Flight departs from Montgomery Regional Airport at 0615.
#     Arrival at 0806 in Hartsfield-Jackson Atlanta International Airport
#     69 minutes layover time.
#     Next leg departs at 0915 and lands at 0923 in Northwest Florida Beaches International Airport
#
#
#     Flight departs from Montgomery Regional Airport at 0615.
#     Arrival at 0806 in Hartsfield-Jackson Atlanta International Airport
#     99 minutes layover time.
#     Next leg departs at 0945 and lands at 1141 in Key West International Airport
#
#
#     Flight departs from Montgomery Regional Airport at 0615.
#     Arrival at 0806 in Hartsfield-Jackson Atlanta International Airport
#     104 minutes layover time.
#     Next leg departs at 0950 and lands at 1150 in Fort Lauderdale-Hollywood International Airport
#
#
#     Flight departs from Montgomery Regional Airport at 0615.
#     Arrival at 0806 in Hartsfield-Jackson Atlanta International Airport
#     64 minutes layover time.
#     Next leg departs at 0910 and lands at 1105 in Fort Lauderdale-Hollywood International Airport
#
#
#     Flight departs from Montgomery Regional Airport at 0615.
#     Arrival at 0806 in Hartsfield-Jackson Atlanta International Airport
#     114 minutes layover time.
#     Next leg departs at 1000 and lands at 1200 in Fort Lauderdale-Hollywood International Airport
#
#
#     Flight departs from Montgomery Regional Airport at 0615.
#     Arrival at 0806 in Hartsfield-Jackson Atlanta International Airport
#     109 minutes layover time.
#     Next leg departs at 0955 and lands at 1102 in Jacksonville International Airport
#
#
#     Flight departs from Montgomery Regional Airport at 0615.
#     Arrival at 0806 in Hartsfield-Jackson Atlanta International Airport
#     109 minutes layover time.
#     Next leg departs at 0955 and lands at 1130 in Orlando International Airport
#
#
#     Flight departs from Montgomery Regional Airport at 0615.
#     Arrival at 0806 in Hartsfield-Jackson Atlanta International Airport
#     114 minutes layover time.
#     Next leg departs at 1000 and lands at 1202 in Miami International Airport
#
#
#     Flight departs from Montgomery Regional Airport at 0615.
#     Arrival at 0806 in Hartsfield-Jackson Atlanta International Airport
#     86 minutes layover time.
#     Next leg departs at 0932 and lands at 1107 in Melbourne International Airport
#
#
#     Flight departs from Montgomery Regional Airport at 0615.
#     Arrival at 0806 in Hartsfield-Jackson Atlanta International Airport
#     67 minutes layover time.
#     Next leg departs at 0913 and lands at 1042 in Melbourne International Airport
#
#
#     Flight departs from Montgomery Regional Airport at 0615.
#     Arrival at 0806 in Hartsfield-Jackson Atlanta International Airport
#     105 minutes layover time.
#     Next leg departs at 0951 and lands at 1145 in Palm Beach International Airport
#
#
#     Flight departs from Montgomery Regional Airport at 0615.
#     Arrival at 0806 in Hartsfield-Jackson Atlanta International Airport
#     64 minutes layover time.
#     Next leg departs at 0910 and lands at 1055 in Southwest Florida International Airport
#
#
#     Flight departs from Montgomery Regional Airport at 0615.
#     Arrival at 0806 in Hartsfield-Jackson Atlanta International Airport
#     74 minutes layover time.
#     Next leg departs at 0920 and lands at 1104 in Southwest Florida International Airport
#
#
#     Flight departs from Montgomery Regional Airport at 0615.
#     Arrival at 0806 in Hartsfield-Jackson Atlanta International Airport
#     93 minutes layover time.
#     Next leg departs at 0939 and lands at 1123 in Southwest Florida International Airport
#
#
#     Flight departs from Montgomery Regional Airport at 0615.
#     Arrival at 0806 in Hartsfield-Jackson Atlanta International Airport
#     69 minutes layover time.
#     Next leg departs at 0915 and lands at 1048 in Sarasota-Bradenton International Airport
#
#
#     Flight departs from Montgomery Regional Airport at 0615.
#     Arrival at 0806 in Hartsfield-Jackson Atlanta International Airport
#     89 minutes layover time.
#     Next leg departs at 0935 and lands at 1103 in Tampa International Airport
#
#
#     Flight departs from Montgomery Regional Airport at 0615.
#     Arrival at 0806 in Hartsfield-Jackson Atlanta International Airport
#     79 minutes layover time.
#     Next leg departs at 0925 and lands at 1055 in Tampa International Airport
#
#
#     Flight departs from Montgomery Regional Airport at 0615.
#     Arrival at 0806 in Hartsfield-Jackson Atlanta International Airport
#     104 minutes layover time.
#     Next leg departs at 0950 and lands at 1120 in Tampa International Airport
#
#
#     Flight departs from Montgomery Regional Airport at 1358.
#     Arrival at 1551 in Hartsfield-Jackson Atlanta International Airport
#     69 minutes layover time.
# ...
#
#
#     Flight departs from Montgomery Regional Airport at 0927.
#     Arrival at 1123 in Hartsfield-Jackson Atlanta International Airport
#     62 minutes layover time.
#     Next leg departs at 1225 and lands at 1350 in Orlando International Airport
#
#
#     Flight departs from Montgomery Regional Airport at 0927.
#     Arrival at 1123 in Hartsfield-Jackson Atlanta International Airport
#     77 minutes layover time.
#     Next leg departs at 1240 and lands at 1405 in Tampa International Airport
#
#
#     Flight departs from Montgomery Regional Airport at 0927.
#     Arrival at 1123 in Hartsfield-Jackson Atlanta International Airport
#     67 minutes layover time.
#     Next leg departs at 1230 and lands at 1244 in Destin-Fort Walton Beach Airport/Eglin AFB
#
#
#     Flight departs from Montgomery Regional Airport at 1720.
#     Arrival at 1930 in Dallas/Fort Worth International Airport
#     70 minutes layover time.
#     Next leg departs at 2040 and lands at 0015 in Fort Lauderdale-Hollywood International Airport
#
#
#     Flight departs from Montgomery Regional Airport at 1720.
#     Arrival at 1930 in Dallas/Fort Worth International Airport
#     65 minutes layover time.
#     Next leg departs at 2035 and lands at 0011 in Miami International Airport
#
#
#     Flight departs from Montgomery Regional Airport at 1720.
#     Arrival at 1930 in Dallas/Fort Worth International Airport
#     65 minutes layover time.
#     Next leg departs at 2035 and lands at 0005 in Palm Beach International Airport
#
#
#     Flight departs from Montgomery Regional Airport at 1720.
#     Arrival at 1930 in Dallas/Fort Worth International Airport
#     70 minutes layover time.
#     Next leg departs at 2040 and lands at 2355 in Tampa International Airport
#
#
#     Flight departs from Montgomery Regional Airport at 1518.
#     Arrival at 1711 in Hartsfield-Jackson Atlanta International Airport
#     119 minutes layover time.
#     Next leg departs at 1910 and lands at 2100 in Key West International Airport
#
#
#     Flight departs from Montgomery Regional Airport at 1518.
#     Arrival at 1711 in Hartsfield-Jackson Atlanta International Airport
#     104 minutes layover time.
#     Next leg departs at 1855 and lands at 2050 in Fort Lauderdale-Hollywood International Airport
#
#
#     Flight departs from Montgomery Regional Airport at 1518.
#     Arrival at 1711 in Hartsfield-Jackson Atlanta International Airport
#     79 minutes layover time.
#     Next leg departs at 1830 and lands at 2025 in Fort Lauderdale-Hollywood International Airport
#
#
#     Flight departs from Montgomery Regional Airport at 1518.
#     Arrival at 1711 in Hartsfield-Jackson Atlanta International Airport
#     104 minutes layover time.
#     Next leg departs at 1855 and lands at 2027 in Orlando International Airport
#
#
#     Flight departs from Montgomery Regional Airport at 1518.
#     Arrival at 1711 in Hartsfield-Jackson Atlanta International Airport
#     119 minutes layover time.
#     Next leg departs at 1910 and lands at 2106 in Miami International Airport
#
#
#     Flight departs from Montgomery Regional Airport at 1518.
#     Arrival at 1711 in Hartsfield-Jackson Atlanta International Airport
#     99 minutes layover time.
#     Next leg departs at 1850 and lands at 2045 in Palm Beach International Airport
#
#
#     Flight departs from Mobile Regional Airport at 0911.
#     Arrival at 1045 in George Bush Intercontinental Airport
#     82 minutes layover time.
#     Next leg departs at 1207 and lands at 1518 in Orlando International Airport
#
#
#     Flight departs from Mobile Regional Airport at 0911.
#     Arrival at 1045 in George Bush Intercontinental Airport
#     105 minutes layover time.
#     Next leg departs at 1230 and lands at 1555 in Miami International Airport
#
#
#     Flight departs from Mobile Regional Airport at 0915.
#     Arrival at 1124 in Hartsfield-Jackson Atlanta International Airport
#     100 minutes layover time.
#     Next leg departs at 1304 and lands at 1310 in Northwest Florida Beaches International Airport
#
#
#     Flight departs from Mobile Regional Airport at 0915.
#     Arrival at 1124 in Hartsfield-Jackson Atlanta International Airport
#     96 minutes layover time.
#     Next leg departs at 1300 and lands at 1452 in Fort Lauderdale-Hollywood International Airport
#
#
#     Flight departs from Mobile Regional Airport at 0915.
#     Arrival at 1124 in Hartsfield-Jackson Atlanta International Airport
#     101 minutes layover time.
#     Next leg departs at 1305 and lands at 1412 in Jacksonville International Airport
#
#
#     Flight departs from Mobile Regional Airport at 0915.
#     Arrival at 1124 in Hartsfield-Jackson Atlanta International Airport
#     61 minutes layover time.
#     Next leg departs at 1225 and lands at 1350 in Orlando International Airport
#
#
#     Flight departs from Mobile Regional Airport at 0915.
#     Arrival at 1124 in Hartsfield-Jackson Atlanta International Airport
#     76 minutes layover time.
#     Next leg departs at 1240 and lands at 1405 in Tampa International Airport
#
#
#     Flight departs from Mobile Regional Airport at 0915.
#     Arrival at 1124 in Hartsfield-Jackson Atlanta International Airport
#     66 minutes layover time.
#     Next leg departs at 1230 and lands at 1244 in Destin-Fort Walton Beach Airport/Eglin AFB
#
#
#     Flight departs from Mobile Regional Airport at 0750.
#     Arrival at 0926 in George Bush Intercontinental Airport
#     97 minutes layover time.
#     Next leg departs at 1103 and lands at 1424 in Miami International Airport
#
#
#     Flight departs from Mobile Regional Airport at 0750.
#     Arrival at 0926 in George Bush Intercontinental Airport
#     64 minutes layover time.
#     Next leg departs at 1030 and lands at 1342 in Southwest Florida International Airport
#
#
#     Flight departs from Mobile Regional Airport at 1318.
#     Arrival at 1544 in Chicago O'Hare International Airport
#     106 minutes layover time.
#     Next leg departs at 1730 and lands at 2136 in Fort Lauderdale-Hollywood International Airport
#
#
#     Flight departs from Mobile Regional Airport at 1318.
#     Arrival at 1544 in Chicago O'Hare International Airport
#     97 minutes layover time.
#     Next leg departs at 1721 and lands at 2112 in Southwest Florida International Airport
#
#
#     Flight departs from Mobile Regional Airport at 0615.
#     Arrival at 0823 in Hartsfield-Jackson Atlanta International Airport
#     69 minutes layover time.
#     Next leg departs at 0932 and lands at 1051 in Daytona Beach International Airport
#
#
#     Flight departs from Mobile Regional Airport at 0615.
#     Arrival at 0823 in Hartsfield-Jackson Atlanta International Airport
#     82 minutes layover time.
#     Next leg departs at 0945 and lands at 1141 in Key West International Airport
#
#
#     Flight departs from Mobile Regional Airport at 0615.
#     Arrival at 0823 in Hartsfield-Jackson Atlanta International Airport
#     87 minutes layover time.
#     Next leg departs at 0950 and lands at 1150 in Fort Lauderdale-Hollywood International Airport
#
#
#     Flight departs from Mobile Regional Airport at 0615.
#     Arrival at 0823 in Hartsfield-Jackson Atlanta International Airport
#     97 minutes layover time.
#     Next leg departs at 1000 and lands at 1200 in Fort Lauderdale-Hollywood International Airport
#
#
#     Flight departs from Mobile Regional Airport at 0615.
#     Arrival at 0823 in Hartsfield-Jackson Atlanta International Airport
#     112 minutes layover time.
#     Next leg departs at 1015 and lands at 1213 in Fort Lauderdale-Hollywood International Airport
#
#
#     Flight departs from Mobile Regional Airport at 0615.
#     Arrival at 0823 in Hartsfield-Jackson Atlanta International Airport
#     92 minutes layover time.
#     Next leg departs at 0955 and lands at 1102 in Jacksonville International Airport
#
#
#     Flight departs from Mobile Regional Airport at 0615.
#     Arrival at 0823 in Hartsfield-Jackson Atlanta International Airport
#     92 minutes layover time.
#     Next leg departs at 0955 and lands at 1130 in Orlando International Airport
#
#
#     Flight departs from Mobile Regional Airport at 0615.
#     Arrival at 0823 in Hartsfield-Jackson Atlanta International Airport
#     97 minutes layover time.
#     Next leg departs at 1000 and lands at 1202 in Miami International Airport
#
#
#     Flight departs from Mobile Regional Airport at 0615.
#     Arrival at 0823 in Hartsfield-Jackson Atlanta International Airport
#     69 minutes layover time.
#     Next leg departs at 0932 and lands at 1107 in Melbourne International Airport
#
#
#     Flight departs from Mobile Regional Airport at 0615.
#     Arrival at 0823 in Hartsfield-Jackson Atlanta International Airport
#     88 minutes layover time.
#     Next leg departs at 0951 and lands at 1145 in Palm Beach International Airport
#
#
#     Flight departs from Mobile Regional Airport at 0615.
#     Arrival at 0823 in Hartsfield-Jackson Atlanta International Airport
#     76 minutes layover time.
#     Next leg departs at 0939 and lands at 1123 in Southwest Florida International Airport
#
#
#     Flight departs from Mobile Regional Airport at 0615.
#     Arrival at 0823 in Hartsfield-Jackson Atlanta International Airport
#     72 minutes layover time.
#     Next leg departs at 0935 and lands at 1103 in Tampa International Airport
#
#
#     Flight departs from Mobile Regional Airport at 0615.
#     Arrival at 0823 in Hartsfield-Jackson Atlanta International Airport
#     62 minutes layover time.
#     Next leg departs at 0925 and lands at 1055 in Tampa International Airport
#
#
#     Flight departs from Mobile Regional Airport at 0615.
#     Arrival at 0823 in Hartsfield-Jackson Atlanta International Airport
#     87 minutes layover time.
#     Next leg departs at 0950 and lands at 1120 in Tampa International Airport
#
#
#     Flight departs from Mobile Regional Airport at 1210.
#     Arrival at 1400 in Dallas/Fort Worth International Airport
#     115 minutes layover time.
#     Next leg departs at 1555 and lands at 1921 in Orlando International Airport
#
#
#     Flight departs from Mobile Regional Airport at 1210.
#     Arrival at 1400 in Dallas/Fort Worth International Airport
#     110 minutes layover time.
#     Next leg departs at 1550 and lands at 1915 in Orlando International Airport
#
#
#     Flight departs from Mobile Regional Airport at 1210.
#     Arrival at 1400 in Dallas/Fort Worth International Airport
#     75 minutes layover time.
#     Next leg departs at 1515 and lands at 1858 in Miami International Airport
#
#
#     Flight departs from Mobile Regional Airport at 1210.
#     Arrival at 1400 in Dallas/Fort Worth International Airport
#     70 minutes layover time.
#     Next leg departs at 1510 and lands at 1653 in Pensacola International Airport (Pensacola Gulf Coast Regional Airport)
#
#
#     Flight departs from Mobile Regional Airport at 0600.
#     Arrival at 0750 in Dallas/Fort Worth International Airport
#     100 minutes layover time.
#     Next leg departs at 0930 and lands at 1255 in Orlando International Airport
#
#
#     Flight departs from Mobile Regional Airport at 0600.
#     Arrival at 0750 in Dallas/Fort Worth International Airport
#     85 minutes layover time.
#     Next leg departs at 0915 and lands at 1250 in Palm Beach International Airport
#
#
#     Flight departs from Mobile Regional Airport at 0600.
#     Arrival at 0750 in Dallas/Fort Worth International Airport
#     95 minutes layover time.
#     Next leg departs at 0925 and lands at 1250 in Southwest Florida International Airport
#
#
#     Flight departs from Mobile Regional Airport at 1300.
#     Arrival at 1512 in Hartsfield-Jackson Atlanta International Airport
#     98 minutes layover time.
#     Next leg departs at 1650 and lands at 1659 in Northwest Florida Beaches International Airport
#
#
#     Flight departs from Mobile Regional Airport at 1300.
#     Arrival at 1512 in Hartsfield-Jackson Atlanta International Airport
#     108 minutes layover time.
#     Next leg departs at 1700 and lands at 1852 in Fort Lauderdale-Hollywood International Airport
#
#
#     Flight departs from Mobile Regional Airport at 1300.
#     Arrival at 1512 in Hartsfield-Jackson Atlanta International Airport
#     88 minutes layover time.
#     Next leg departs at 1640 and lands at 1752 in Gainesville Regional Airport
#
#
#     Flight departs from Mobile Regional Airport at 1300.
#     Arrival at 1512 in Hartsfield-Jackson Atlanta International Airport
#     103 minutes layover time.
#     Next leg departs at 1655 and lands at 1821 in Orlando International Airport
#
#
#     Flight departs from Mobile Regional Airport at 1300.
#     Arrival at 1512 in Hartsfield-Jackson Atlanta International Airport
#     68 minutes layover time.
#     Next leg departs at 1620 and lands at 1750 in Orlando International Airport
#
#
#     Flight departs from Mobile Regional Airport at 1300.
#     Arrival at 1512 in Hartsfield-Jackson Atlanta International Airport
#     108 minutes layover time.
#     Next leg departs at 1700 and lands at 1840 in Southwest Florida International Airport
#
#
#     Flight departs from Mobile Regional Airport at 1300.
#     Arrival at 1512 in Hartsfield-Jackson Atlanta International Airport
#     73 minutes layover time.
#     Next leg departs at 1625 and lands at 1809 in Southwest Florida International Airport
#
#
#     Flight departs from Mobile Regional Airport at 1300.
#     Arrival at 1512 in Hartsfield-Jackson Atlanta International Airport
#     83 minutes layover time.
#     Next leg departs at 1635 and lands at 1803 in Tampa International Airport
#
#
#     Flight departs from Mobile Regional Airport at 1635.
#     Arrival at 1850 in Hartsfield-Jackson Atlanta International Airport
#     65 minutes layover time.
#     Next leg departs at 1955 and lands at 2146 in Fort Lauderdale-Hollywood International Airport
#
#
#     Flight departs from Mobile Regional Airport at 1635.
#     Arrival at 1850 in Hartsfield-Jackson Atlanta International Airport
#     115 minutes layover time.
#     Next leg departs at 2045 and lands at 2235 in Fort Lauderdale-Hollywood International Airport
#
#
#     Flight departs from Mobile Regional Airport at 1635.
#     Arrival at 1850 in Hartsfield-Jackson Atlanta International Airport
#     90 minutes layover time.
#     Next leg departs at 2020 and lands at 2215 in Fort Lauderdale-Hollywood International Airport
#
#
#     Flight departs from Mobile Regional Airport at 1635.
#     Arrival at 1850 in Hartsfield-Jackson Atlanta International Airport
#     115 minutes layover time.
#     Next leg departs at 2045 and lands at 2153 in Jacksonville International Airport
#
#
#     Flight departs from Mobile Regional Airport at 1635.
#     Arrival at 1850 in Hartsfield-Jackson Atlanta International Airport
#     65 minutes layover time.
#     Next leg departs at 1955 and lands at 2123 in Orlando International Airport
#
#
#     Flight departs from Mobile Regional Airport at 1635.
#     Arrival at 1850 in Hartsfield-Jackson Atlanta International Airport
#     70 minutes layover time.
#     Next leg departs at 2000 and lands at 2125 in Orlando International Airport
#
#
#     Flight departs from Mobile Regional Airport at 1635.
#     Arrival at 1850 in Hartsfield-Jackson Atlanta International Airport
#     65 minutes layover time.
#     Next leg departs at 1955 and lands at 2146 in Palm Beach International Airport
#
#
#     Flight departs from Mobile Regional Airport at 1635.
#     Arrival at 1850 in Hartsfield-Jackson Atlanta International Airport
#     61 minutes layover time.
#     Next leg departs at 1951 and lands at 2007 in Pensacola International Airport (Pensacola Gulf Coast Regional Airport)
#
#
#     Flight departs from Mobile Regional Airport at 1635.
#     Arrival at 1850 in Hartsfield-Jackson Atlanta International Airport
#     69 minutes layover time.
#     Next leg departs at 1959 and lands at 2140 in Southwest Florida International Airport
#
#
#     Flight departs from Mobile Regional Airport at 1635.
#     Arrival at 1850 in Hartsfield-Jackson Atlanta International Airport
#     111 minutes layover time.
#     Next leg departs at 2041 and lands at 2204 in Tampa International Airport

# %%
results, time = NeoQuery(
    """
    MATCH (ord:Airport {iata: 'ATL'})-[:HAS_DEPARTURE]->(fl:Flight)-[:OPERATED_BY]->(al:Airline {iata: 'AA'})
    RETURN fl
    """
).query(500)

print(time)
[record['fl']['flight_number'] for record in results]
# Out:
# 6.334895058999997
# ['314',
#  '17',
#  '356',
#  '1513',
#  '1652',
#  '276',
#  '1635',
#  '1513',
#  '1473',
#  '194',
#  '1455',
#  '232',
#  '1455',
#  '349',
#  '1635',
#  '1652',
#  '17',
#  '125']

# %%
results, time = NeoQuery(
    """
    MATCH (:Airport {iata: 'ATL'})-[:HAS_DEPARTURE]->(fl:Flight)-[:FLIES_TO]->(ar:Airport {iata: 'CLT'})
    RETURN fl
    """
).query(500)

print(time)
[record['fl']['flight_number'] for record in results]
# Out:
# 4.48958657
# ['889',
#  '447',
#  '1805',
#  '1808',
#  '1808',
#  '461',
#  '1744',
#  '1999',
#  '2052',
#  '1441',
#  '2065',
#  '1095',
#  '2133',
#  '1076',
#  '461',
#  '2251',
#  '1095',
#  '2065',
#  '658']

# %% [markdown]
# Query for All flights with a specific tail number

# %%
results, time = NeoQuery(
    """
    MATCH (ar:Airport)-[:HAS_DEPARTURE]->(fl:Flight)-[:USES]->(tl:Tail {number: 'N129DL'})
    RETURN distinct fl
    """
).query(200)

print(time)
[record for record in results]
# Out:
# 2.9167485919999976
# [<Record fl=<Node id=466784 labels={'Flight'} properties={'wheels_off': '1422', 'taxi_in': '7', 'distance': '2139', 'year': '2015', 'scheduled_time': '269', 'scheduled_arrival': '2139', 'diverted': '0', 'taxi_out': '12', 'tail_number': 'N129DL', 'elapsed_time': '258', 'air_time': '239', 'airline': 'DL', 'departure_time': '1410', 'day': '1', 'departure_delay': '0', 'day_of_week': '4', 'arrival_time': '2128', 'wheels_on': '2121', 'flight_number': '61', 'origin_airport': 'SFO', 'destination_airport': 'ATL', 'month': '1', 'cancelled': '0', 'scheduled_departure': '1410', 'arrival_delay': '-11'}>>,
#  <Record fl=<Node id=494253 labels={'Flight'} properties={'wheels_off': '0729', 'taxi_in': '7', 'distance': '1590', 'year': '2015', 'scheduled_time': '260', 'scheduled_arrival': '0940', 'diverted': '0', 'taxi_out': '11', 'tail_number': 'N129DL', 'elapsed_time': '238', 'air_time': '220', 'airline': 'DL', 'departure_time': '0718', 'day': '2', 'departure_delay': '-2', 'day_of_week': '5', 'arrival_time': '0916', 'wheels_on': '0909', 'flight_number': '331', 'origin_airport': 'ATL', 'destination_airport': 'SLC', 'month': '1', 'cancelled': '0', 'scheduled_departure': '0720', 'arrival_delay': '-24'}>>,
#  <Record fl=<Node id=460084 labels={'Flight'} properties={'wheels_off': '1100', 'taxi_in': '8', 'distance': '2139', 'year': '2015', 'scheduled_time': '330', 'scheduled_arrival': '1310', 'diverted': '0', 'taxi_out': '17', 'tail_number': 'N129DL', 'elapsed_time': '302', 'air_time': '277', 'airline': 'DL', 'departure_time': '1043', 'day': '1', 'departure_delay': '3', 'day_of_week': '4', 'arrival_time': '1245', 'wheels_on': '1237', 'flight_number': '1680', 'origin_airport': 'ATL', 'destination_airport': 'SFO', 'month': '1', 'cancelled': '0', 'scheduled_departure': '1040', 'arrival_delay': '-25'}>>,
#  <Record fl=<Node id=501893 labels={'Flight'} properties={'wheels_off': '1108', 'taxi_in': '7', 'distance': '1590', 'year': '2015', 'scheduled_time': '212', 'scheduled_arrival': '1632', 'diverted': '0', 'taxi_out': '12', 'tail_number': 'N129DL', 'elapsed_time': '202', 'air_time': '183', 'airline': 'DL', 'departure_time': '1056', 'day': '2', 'departure_delay': '-4', 'day_of_week': '5', 'arrival_time': '1618', 'wheels_on': '1611', 'flight_number': '1912', 'origin_airport': 'SLC', 'destination_airport': 'ATL', 'month': '1', 'cancelled': '0', 'scheduled_departure': '1100', 'arrival_delay': '-14'}>>]

# %% [markdown]
# Query for all flights with specific tail number, but this query is slower

# %%
results, time = NeoQuery(
    """
    MATCH (ar:Airport)-[:HAS_DEPARTURE]->(fl:Flight {tail_number: 'N129DL'})
    RETURN fl
    """
).query(200)

print(time)
[record for record in results]
# Out:
# 9.947114249000009
# [<Record fl=<Node id=460084 labels={'Flight'} properties={'wheels_off': '1100', 'taxi_in': '8', 'distance': '2139', 'year': '2015', 'scheduled_time': '330', 'scheduled_arrival': '1310', 'diverted': '0', 'taxi_out': '17', 'tail_number': 'N129DL', 'elapsed_time': '302', 'air_time': '277', 'airline': 'DL', 'departure_time': '1043', 'day': '1', 'departure_delay': '3', 'day_of_week': '4', 'arrival_time': '1245', 'wheels_on': '1237', 'flight_number': '1680', 'origin_airport': 'ATL', 'destination_airport': 'SFO', 'month': '1', 'cancelled': '0', 'scheduled_departure': '1040', 'arrival_delay': '-25'}>>,
#  <Record fl=<Node id=494253 labels={'Flight'} properties={'wheels_off': '0729', 'taxi_in': '7', 'distance': '1590', 'year': '2015', 'scheduled_time': '260', 'scheduled_arrival': '0940', 'diverted': '0', 'taxi_out': '11', 'tail_number': 'N129DL', 'elapsed_time': '238', 'air_time': '220', 'airline': 'DL', 'departure_time': '0718', 'day': '2', 'departure_delay': '-2', 'day_of_week': '5', 'arrival_time': '0916', 'wheels_on': '0909', 'flight_number': '331', 'origin_airport': 'ATL', 'destination_airport': 'SLC', 'month': '1', 'cancelled': '0', 'scheduled_departure': '0720', 'arrival_delay': '-24'}>>,
#  <Record fl=<Node id=466784 labels={'Flight'} properties={'wheels_off': '1422', 'taxi_in': '7', 'distance': '2139', 'year': '2015', 'scheduled_time': '269', 'scheduled_arrival': '2139', 'diverted': '0', 'taxi_out': '12', 'tail_number': 'N129DL', 'elapsed_time': '258', 'air_time': '239', 'airline': 'DL', 'departure_time': '1410', 'day': '1', 'departure_delay': '0', 'day_of_week': '4', 'arrival_time': '2128', 'wheels_on': '2121', 'flight_number': '61', 'origin_airport': 'SFO', 'destination_airport': 'ATL', 'month': '1', 'cancelled': '0', 'scheduled_departure': '1410', 'arrival_delay': '-11'}>>,
#  <Record fl=<Node id=501893 labels={'Flight'} properties={'wheels_off': '1108', 'taxi_in': '7', 'distance': '1590', 'year': '2015', 'scheduled_time': '212', 'scheduled_arrival': '1632', 'diverted': '0', 'taxi_out': '12', 'tail_number': 'N129DL', 'elapsed_time': '202', 'air_time': '183', 'airline': 'DL', 'departure_time': '1056', 'day': '2', 'departure_delay': '-4', 'day_of_week': '5', 'arrival_time': '1618', 'wheels_on': '1611', 'flight_number': '1912', 'origin_airport': 'SLC', 'destination_airport': 'ATL', 'month': '1', 'cancelled': '0', 'scheduled_departure': '1100', 'arrival_delay': '-14'}>>]
